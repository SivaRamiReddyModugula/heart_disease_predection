# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
style.use('ggplot')
import seaborn as sns
plt.rcParams['figure.figsize']=(15,10)

# %%
df=pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000182DB28B848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E0158088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E03A9C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E03E2C48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000182E041BD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E0662E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E069BF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E06D70C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000182E06DDC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E0717E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E07813C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182E07BA448>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000182DFAEC248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182DFAE2B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182DFF24448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000182DFCC6B08>]],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
labels=['trestbps', 'chol', 'thalach', 'oldpeak']

# %%
for label in labels:
    print(label)
    print(df[lable].describe())
    print(df[label].unique())
    sns.boxplot(df[label])
    plt.show()
# Out:
# trestbps
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64
# [61]
# chol
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64
# [212 203 174 294 248 318 289 249 286 149 341 210 298 204 308 266 244 211
#  185 223 208 252 209 307 233 319 256 327 169 131 269 196 231 213 271 263
#  229 360 258 330 342 226 228 278 230 283 241 175 188 217 193 245 232 299
#  288 197 315 215 164 326 207 177 257 255 187 201 220 268 267 236 303 282
#  126 309 186 275 281 206 335 218 254 295 417 260 240 302 192 225 325 235
#  274 234 182 167 172 321 300 199 564 157 304 222 184 354 160 247 239 246
#  409 293 180 250 221 200 227 243 311 261 242 205 306 219 353 198 394 183
#  237 224 265 313 340 259 270 216 264 276 322 214 273 253 176 284 305 168
#  407 290 277 262 195 166 178 141]
# thalach
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64
# [168 155 125 161 106 122 140 145 144 116 136 192 156 142 109 162 165 148
#  172 173 146 179 152 117 115 112 163 147 182 105 150 151 169 166 178 132
#  160 123 139 111 180 164 202 157 159 170 138 175 158 126 143 141 167  95
#  190 118 103 181 108 177 134 120 171 149 154 153  88 174 114 195 133  96
#  124 131 185 194 128 127 186 184 188 130  71 137  99 121 187  97  90 129
#  113]
# oldpeak
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64
# [1.  3.1 2.6 0.  1.9 4.4 0.8 3.2 1.6 3.  0.7 4.2 1.5 2.2 1.1 0.3 0.4 0.6
#  3.4 2.8 1.2 2.9 3.6 1.4 0.2 2.  5.6 0.9 1.8 6.2 4.  2.5 0.5 0.1 2.1 2.4
#  3.8 2.3 1.3 3.5]

# %%
# IQR

df['trestbps']=np.where(df['trestbps']>=140,140,df['trestbps'])
